# %%
import requests
import json
from itertools import chain
import pandas as pd

# %%
MAPPING_URL = 'http://data.bioontology.org/ontologies/ATC/mappings'
API_KEY = '8b5b7825-538d-40e0-9e9e-5ab9274a9aeb'
MAPPINGS_FILE = 'mappings.json'

# %%
# Get some sample data (one page)
result = requests.get(MAPPING_URL, params={'apikey':API_KEY})

j = result.json()

display(j)
# Out:
# {'page': 1,
#  'pageCount': 4760,
#  'totalCount': 237959,
#  'prevPage': None,
#  'nextPage': 2,
#  'links': {'nextPage': 'http://data.bioontology.org/ontologies/ATC/mappings?apikey=8b5b7825-538d-40e0-9e9e-5ab9274a9aeb&page=2',
#   'prevPage': None},
#  'collection': [{'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/NDDF/010500',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500',
#       'ontology': 'http://data.bioontology.org/ontologies/NDDF',
#       'children': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/children',
#       'parents': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/instances',
#       'tree': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/tree',
#       'notes': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/NDDF?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/MSHFRE/D012828',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828',
#       'ontology': 'http://data.bioontology.org/ontologies/MSHFRE',
#       'children': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/children',
#       'parents': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/instances',
#       'tree': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/tree',
#       'notes': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/MSHFRE?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/MESH/D012828',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828',
#       'ontology': 'http://data.bioontology.org/ontologies/MESH',
#       'children': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/children',
#       'parents': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/instances',
#       'tree': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/tree',
#       'notes': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/MESH?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'LOOM',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/MESH/D012828',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828',
#       'ontology': 'http://data.bioontology.org/ontologies/MESH',
#       'children': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/children',
#       'parents': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/instances',
#       'tree': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/tree',
#       'notes': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/MESH?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/SCTSPA/350103006',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006',
#       'ontology': 'http://data.bioontology.org/ontologies/SCTSPA',
#       'children': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/children',
#       'parents': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/instances',
#       'tree': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/tree',
#       'notes': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/SCTSPA?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/RXNORM/9778',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778',
#       'ontology': 'http://data.bioontology.org/ontologies/RXNORM',
#       'children': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/children',
#       'parents': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/instances',
#       'tree': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/tree',
#       'notes': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/RXNORM?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'LOOM',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/RXNORM/9778',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778',
#       'ontology': 'http://data.bioontology.org/ontologies/RXNORM',
#       'children': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/children',
#       'parents': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/instances',
#       'tree': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/tree',
#       'notes': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/RXNORM?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/VANDF/4019427',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427',
#       'ontology': 'http://data.bioontology.org/ontologies/VANDF',
#       'children': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/children',
#       'parents': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/instances',
#       'tree': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/tree',
#       'notes': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/VANDF?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/SNMI/C-22301',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301',
#       'ontology': 'http://data.bioontology.org/ontologies/SNMI',
#       'children': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/children',
#       'parents': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/instances',
#       'tree': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/tree',
#       'notes': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/SNMI?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'LOOM',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/A03AX13',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://id.loc.gov/authorities/subjects/sh85122534',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534',
#       'ontology': 'http://data.bioontology.org/ontologies/LC-SUBJECTS',
#       'children': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/children',
#       'parents': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/instances',
#       'tree': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/tree',
#       'notes': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/mappings',
# ...
#       'notes': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F96056009/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F96056009/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/SCTSPA?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F96056009',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/J01DB07',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/LNC/MTHU008442',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442',
#       'ontology': 'http://data.bioontology.org/ontologies/LOINC',
#       'children': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/children',
#       'parents': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/instances',
#       'tree': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/tree',
#       'notes': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/LOINC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'LOOM',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/J01DB07',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/LNC/MTHU008442',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442',
#       'ontology': 'http://data.bioontology.org/ontologies/LOINC',
#       'children': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/children',
#       'parents': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/instances',
#       'tree': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/tree',
#       'notes': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/LOINC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'},
#   {'id': None,
#    'source': 'CUI',
#    'classes': [{'@id': 'http://purl.bioontology.org/ontology/UATC/J01DB07',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       'ontology': 'http://data.bioontology.org/ontologies/ATC',
#       'children': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/children',
#       'parents': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/instances',
#       'tree': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/tree',
#       'notes': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/ATC?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}},
#     {'@id': 'http://purl.bioontology.org/ontology/SNMI/C-53640',
#      '@type': 'http://www.w3.org/2002/07/owl#Class',
#      'links': {'self': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640',
#       'ontology': 'http://data.bioontology.org/ontologies/SNMI',
#       'children': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/children',
#       'parents': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/parents',
#       'descendants': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/descendants',
#       'ancestors': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/ancestors',
#       'instances': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/instances',
#       'tree': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/tree',
#       'notes': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/notes',
#       'mappings': 'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/mappings',
#       'ui': 'http://bioportal.bioontology.org/ontologies/SNMI?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640',
#       '@context': {'self': 'http://www.w3.org/2002/07/owl#Class',
#        'ontology': 'http://data.bioontology.org/metadata/Ontology',
#        'children': 'http://www.w3.org/2002/07/owl#Class',
#        'parents': 'http://www.w3.org/2002/07/owl#Class',
#        'descendants': 'http://www.w3.org/2002/07/owl#Class',
#        'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#        'instances': 'http://data.bioontology.org/metadata/Instance',
#        'tree': 'http://www.w3.org/2002/07/owl#Class',
#        'notes': 'http://data.bioontology.org/metadata/Note',
#        'mappings': 'http://data.bioontology.org/metadata/Mapping',
#        'ui': 'http://www.w3.org/2002/07/owl#Class'}},
#      '@context': {'@vocab': 'http://data.bioontology.org/metadata/'}}],
#    'process': None,
#    '@id': '',
#    '@type': 'http://data.bioontology.org/metadata/Mapping'}]}

# %%
with open(MAPPINGS_FILE, 'w') as f:
    json.dump(j, f)

# %% [markdown]
# Every page seems to have a "collection" of mappings. Every item in a collection contains a number of classes that have been mapped using the same "source".
#
# For retrieving the mappings per class we have to follow a link.

# %%
# Don't download the data again when it is still available
with open(MAPPINGS_FILE, 'r') as f:
    j = json.load(f)

# %%
# Per class mapping we need the mapping source and mapping link

def get_mappings_per_source(collection):
    for item in collection:
        source = item['source']
        
        for class_mapping in item['classes']:
            yield source, class_mapping['@id'], class_mapping['links']['mappings']

# %%
mappings = get_mappings_per_source(j['collection'])

# %%
pd.DataFrame(mappings, columns=['source', 'class', link])
# Out:
# [('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDDF/010500',
#   'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F010500/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/MSHFRE/D012828',
#   'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD012828/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/MESH/D012828',
#   'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/MESH/D012828',
#   'http://data.bioontology.org/ontologies/MESH/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMESH%2FD012828/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SCTSPA/350103006',
#   'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F350103006/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/RXNORM/9778',
#   'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/RXNORM/9778',
#   'http://data.bioontology.org/ontologies/RXNORM/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRXNORM%2F9778/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/VANDF/4019427',
#   'http://data.bioontology.org/ontologies/VANDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FVANDF%2F4019427/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SNMI/C-22301',
#   'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-22301/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://id.loc.gov/authorities/subjects/sh85122534',
#   'http://data.bioontology.org/ontologies/LC-SUBJECTS/classes/http%3A%2F%2Fid.loc.gov%2Fauthorities%2Fsubjects%2Fsh85122534/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#D05.750.900.850',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23D05.750.900.850/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#D02.715.650.700',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23D02.715.650.700/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SNOMEDCT/13652007',
#   'http://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2F13652007/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/BCCHRCATALOG/D012828',
#   'http://data.bioontology.org/ontologies/BCCHRCATALOG/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FBCCHRCATALOG%2FD012828/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#D25.720.900.850',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23D25.720.900.850/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDFRT/N0000147558',
#   'http://data.bioontology.org/ontologies/NDFRT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDFRT%2FN0000147558/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#J01.637.051.720.900.850',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23J01.637.051.720.900.850/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/RCD/Xa4fv',
#   'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FXa4fv/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/LNC/LP17967-8',
#   'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FLP17967-8/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SNOMEDCT/350103006',
#   'http://data.bioontology.org/ontologies/SNOMEDCT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNOMEDCT%2F350103006/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://localhost/plosthes.2017-1#2778',
#   'http://data.bioontology.org/ontologies/PLOSTHES/classes/http%3A%2F%2Flocalhost%2Fplosthes.2017-1%232778/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDDF/001918',
#   'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F001918/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/NDDF/001918',
#   'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F001918/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00015820',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00015820/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00015820',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00015820/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00015820',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00015820/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00015820',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00015820/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SCTSPA/13652007',
#   'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F13652007/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://sbmi.uth.tmc.edu/ontology/ochv#11347',
#   'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%2311347/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/RCD/x01Gr',
#   'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2Fx01Gr/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#D012828',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23D012828/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/A03AX13',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FA03AX13/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDFRT/N0000006168',
#   'http://data.bioontology.org/ontologies/NDFRT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDFRT%2FN0000006168/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://phenomebrowser.net/ontologies/mesh/mesh.owl#D04.075.080.875.099.221.249.200.165.125',
#   'http://data.bioontology.org/ontologies/RH-MESH/classes/http%3A%2F%2Fphenomebrowser.net%2Fontologies%2Fmesh%2Fmesh.owl%23D04.075.080.875.099.221.249.200.165.125/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDDF/004202',
#   'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F004202/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/NDDF/004202',
#   'http://data.bioontology.org/ontologies/NDDF/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDDF%2F004202/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://snomed.info/id/96056009',
#   'http://data.bioontology.org/ontologies/SNO_COPY/classes/http%3A%2F%2Fsnomed.info%2Fid%2F96056009/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://snomed.info/id/96056009',
#   'http://data.bioontology.org/ontologies/SNO_COPY/classes/http%3A%2F%2Fsnomed.info%2Fid%2F96056009/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/MSHFRE/D002436',
#   'http://data.bioontology.org/ontologies/MSHFRE/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FMSHFRE%2FD002436/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://stirdf.jst.go.jp/id/200907017991587519',
#   'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fstirdf.jst.go.jp%2Fid%2F200907017991587519/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/NDFRT/N0000166880',
#   'http://data.bioontology.org/ontologies/NDFRT/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FNDFRT%2FN0000166880/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00014621',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00014621/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00014621',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00014621/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00014621',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00014621/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.obolibrary.org/obo/DRON_00014621',
#   'http://data.bioontology.org/ontologies/DRON/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FDRON_00014621/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.jp/bio/4/id/200906008092699436',
#   'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906008092699436/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/BCCHRCATALOG/D002436',
#   'http://data.bioontology.org/ontologies/BCCHRCATALOG/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FBCCHRCATALOG%2FD002436/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SCTSPA/96056009',
#   'http://data.bioontology.org/ontologies/SCTSPA/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSCTSPA%2F96056009/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/LNC/MTHU008442',
#   'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('LOOM',
#   'http://purl.bioontology.org/ontology/LNC/MTHU008442',
#   'http://data.bioontology.org/ontologies/LOINC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FLNC%2FMTHU008442/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/UATC/J01DB07',
#   'http://data.bioontology.org/ontologies/ATC/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FUATC%2FJ01DB07/mappings'),
#  ('CUI',
#   'http://purl.bioontology.org/ontology/SNMI/C-53640',
#   'http://data.bioontology.org/ontologies/SNMI/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FSNMI%2FC-53640/mappings')]
