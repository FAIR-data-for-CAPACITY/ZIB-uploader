# %% [markdown]
# # Unnest and cleanup capacity field mapping
# The human-entered mapping from Maastro clinic contains a lot of messy and nested data. We want to clean it, and unnest the data. WARNING: This is messy stuff, it seems to work in 95% of the cases, but there is a small group of diverse edgecases that still go wrong. We can NEVER guarantee that this data is converted correctly because there are sometimes just strings that need to be human-interpreted.

# %%
import pandas as pd
import numpy as np

# %%
cd ..
# Out:
# /Users/svenvanderburg/projects/capacity/ZIB-uploader

# %% [markdown]
# ## Load excel file with mappings entered by humans from Maastro clinic
# File can be found [on the Maastro teams](https://teams.microsoft.com/l/file/CADBAFA2-9EBA-4E19-B8E4-935EA2A7974B?tenantId=b9c5dd0d-b3a0-4572-a670-e4e8bd6c9350&fileType=xlsx&objectUrl=https%3A%2F%2Fmaastro.sharepoint.com%2Fsites%2FO365GroepCDSCARRIERProjectManagement%2FShared%20Documents%2FCAPACITY%2FCodes%20mapping%20(1).xlsx&baseUrl=https%3A%2F%2Fmaastro.sharepoint.com%2Fsites%2FO365GroepCDSCARRIERProjectManagement&serviceName=teams&threadId=19:373f883c850c4e9aa697817c3cc38676@thread.skype&groupId=257a7bbf-43a5-4906-ab8e-c4deb714fc6d) or [on their sharepoint](https://maastro.sharepoint.com/sites/O365GroepCDSCARRIERProjectManagement/_layouts/15/Doc.aspx?OR=teams&action=edit&sourcedoc={CADBAFA2-9EBA-4E19-B8E4-935EA2A7974B}). Talk to Djura for access.

# %%
df = pd.read_excel('data/capacity-human-entered-mapping.xlsx', sheet_name='CAPACITY - required variables')

# %%
df.head(4)
# Out:
#                                  Variable/Field Name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
#
#                                Field Label  \
# 0    Participant Identification Number Pin
# 1  Participant Identification Number (PIN)
# 2                                 STUDY ID
# 3                                  Comple?
#
#                         Fiel Attributes      Zib                  Zib concept  \
# 0                                   NaN      NaN                          NaN
# 1                                  text  Patient  PatientIdentificationNumber
# 2                                  text      NaN                          NaN
# 3  0-Incomplete,1-Unverified,2-Complete      NaN                          NaN
#
#   Zib codesystem        EHR Snomed COD016-VEKT code ICD-10  ATC
# 0            NaN        NaN    NaN              NaN    NaN  NaN
# 1            NaN  pseudonym    NaN              NaN    NaN  NaN
# 2            NaN        NaN    NaN              NaN    NaN  NaN
# 3            NaN        NaN    NaN              NaN    NaN  NaN

# %% [markdown]
# ## Cleanup data

# %%
# Rename columns 
df.columns = ['capacity_field_name', 'capacity_field_description', 'capacity_field_attributes', 'zib', 'zib_concept', 'zib_codesystem', 'ehr', 'snomed', 'cod016_vekt_code', 'icd_10_code', 'atc']

# %%
df.head(6)
# Out:
#                                  capacity_field_name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
# 4                        inclusion_criteria_required
# 5                                            dsstdat
#
#                 capacity_field_description  \
# 0    Participant Identification Number Pin
# 1  Participant Identification Number (PIN)
# 2                                 STUDY ID
# 3                                  Comple?
# 4                       Inclusion Criteria
# 5                       Date of Enrollment
#
#               capacity_field_attributes      zib                  zib_concept  \
# 0                                   NaN      NaN                          NaN
# 1                                  text  Patient  PatientIdentificationNumber
# 2                                  text      NaN                          NaN
# 3  0-Incomplete,1-Unverified,2-Complete      NaN                          NaN
# 4                                   NaN      NaN                          NaN
# 5                            text(date)      NaN                          NaN
#
#   zib_codesystem        ehr snomed cod016_vekt_code icd_10_code  atc
# 0            NaN        NaN    NaN              NaN         NaN  NaN
# 1            NaN  pseudonym    NaN              NaN         NaN  NaN
# 2            NaN        NaN    NaN              NaN         NaN  NaN
# 3            NaN        NaN    NaN              NaN         NaN  NaN
# 4            NaN        NaN    NaN              NaN         NaN  NaN
# 5            NaN        NaN    NaN              NaN         NaN  NaN

# %% [markdown]
# ### Explode `capacity_field_attributes` column

# %%
df['capacity_field_attributes'] = df['capacity_field_attributes'].str.split(r';|,')

# %%
df = df.explode('capacity_field_attributes')
df = df.reset_index(drop=True)

# %%
df.head(10)
# Out:
#                                  capacity_field_name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
# 4  participant_identification_number_pin_required...
# 5  participant_identification_number_pin_required...
# 6                        inclusion_criteria_required
# 7                                            dsstdat
# 8                                       sitename_nhr
# 9                                            country
#
#                 capacity_field_description capacity_field_attributes  \
# 0    Participant Identification Number Pin                       NaN
# 1  Participant Identification Number (PIN)                      text
# 2                                 STUDY ID                      text
# 3                                  Comple?              0-Incomplete
# 4                                  Comple?              1-Unverified
# 5                                  Comple?                2-Complete
# 6                       Inclusion Criteria                       NaN
# 7                       Date of Enrollment                text(date)
# 8                                Site name                       NaN
# 9                                  Country                  text (?)
#
#                   zib                  zib_concept  \
# 0                 NaN                          NaN
# 1             Patient  PatientIdentificationNumber
# 2                 NaN                          NaN
# 3                 NaN                          NaN
# 4                 NaN                          NaN
# 5                 NaN                          NaN
# 6                 NaN                          NaN
# 7                 NaN                          NaN
# 8  HealthcareProvider             OrganizationName
# 9  AddressInformation                      Country
#
#                              zib_codesystem        ehr snomed  \
# 0                                       NaN        NaN    NaN
# 1                                       NaN  pseudonym    NaN
# 2                                       NaN        NaN    NaN
# 3                                       NaN        NaN    NaN
# 4                                       NaN        NaN    NaN
# 5                                       NaN        NaN    NaN
# 6                                       NaN        NaN    NaN
# 7                                       NaN        NaN    NaN
# 8                                       NaN        NaN    NaN
# 9  CountryGBACodelist or CountryISOCodelist        NaN    NaN
#
#   cod016_vekt_code icd_10_code  atc
# 0              NaN         NaN  NaN
# 1              NaN         NaN  NaN
# 2              NaN         NaN  NaN
# 3              NaN         NaN  NaN
# 4              NaN         NaN  NaN
# 5              NaN         NaN  NaN
# 6              NaN         NaN  NaN
# 7              NaN         NaN  NaN
# 8              NaN         NaN  NaN
# 9              NaN         NaN  NaN

# %% [markdown]
# ### Split `capacity_field_attributes` column into `capacity_field_choice_code` and `capacity_field_choice_description`

# %%
def _extract_choice(string, index):
    if pd.isna(string):
        return string
    if '-1' in string:
        # Sometimes -1 is in the string, we can therefore not
        # split on '-', but need to manually do this:
        splitted = ['-1', string.strip('-1 ')]
    else:
        splitted = string.split('-')
        if len(splitted) == 1:
            return np.nan
    return splitted[index].strip()


def extract_choice_code(string):
    """
    i.e. extracts 3 from '3-something'
    """
    return _extract_choice(string, 0)


def extract_choice_description(string):
    """
    i.e. extracts something from '3-something'
    """
    return _extract_choice(string, 1)
    
df['capacity_field_choice_code'] = df['capacity_field_attributes'].apply(extract_choice_code)
df['capacity_field_choice_description'] = df['capacity_field_attributes'].apply(extract_choice_description)

# %%
df[['capacity_field_choice_code', 'capacity_field_choice_description', 'capacity_field_attributes']].head(20)
# Out:
#    capacity_field_choice_code capacity_field_choice_description  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                           0                        Incomplete
# 4                           1                        Unverified
# 5                           2                          Complete
# 6                         NaN                               NaN
# 7                         NaN                               NaN
# 8                         NaN                               NaN
# 9                         NaN                               NaN
# 10                          1                               yes
# 11                          0                                no
# 12                          1                               yes
# 13                          2                                no
# 14                          3                           unknown
# 15                          1                               yes
# 16                          2                                no
# 17                          3                           unknown
# 18                          1                               yes
# 19                          2                                no
#
#    capacity_field_attributes
# 0                        NaN
# 1                       text
# 2                       text
# 3               0-Incomplete
# 4               1-Unverified
# 5                 2-Complete
# 6                        NaN
# 7                 text(date)
# 8                        NaN
# 9                   text (?)
# 10                     1-yes
# 11                      0-no
# 12                     1-yes
# 13                      2-no
# 14                 3-unknown
# 15                     1-yes
# 16                      2-no
# 17                 3-unknown
# 18                     1-yes
# 19                      2-no

# %%
df = df.drop(columns=['capacity_field_attributes'])

# %% [markdown]
# ### Split `snomed` and `atc` column

# %%
df[~pd.isna(df['snomed'])][['capacity_field_name', 'snomed', 'capacity_field_choice_code', 'capacity_field_choice_description']]
# Out:
#     capacity_field_name                                             snomed  \
# 44    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 45    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 46    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 47       labwork_erterm            159138004 | Microbiologist (occupation)
# 48       labwork_erterm            159138004 | Microbiologist (occupation)
# ..                  ...                                                ...
# 430      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 431      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 432      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 433      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 434      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
#
#     capacity_field_choice_code capacity_field_choice_description
# 44                           1                               yes
# 45                           2                                no
# 46                           3                               N/A
# 47                           1                               yes
# 48                           2                                no
# ..                         ...                               ...
# 430                          3             Mitral valve stenosis
# 431                          4        Mitral valve regurgitation
# 432                          5     Pulmonary valve regurgitation
# 433                          7          Tricuspid valve stenosis
# 434                          8     Tricuspid valve regurgitation
#
# [276 rows x 4 columns]

# %% [markdown]
# The snomed and atc fields correspond of pipe-separated text depicting the code and description:

# %%
df.iloc[430]['snomed']
# Out:
# '60573004 | Aortic valve stenosis (disorder) |60234000 | Aortic valve regurgitation (disorder) |48724000 | Mitral valve regurgitation (disorder) |91434003 | Pulmonic valve regurgitation (disorder) 49915006 | Tricuspid valve stenosis (disorder) |111287006 | Tricuspid valve regurgitation (disorder) |'

# %%
def _extract_pipe_separated(group, column):
    pipe_separated_text = group[column].iloc[0]
    if pd.isna(pipe_separated_text):
        codes = [np.nan] * len(group)
        descriptions = [np.nan] * len(group)
    else:
        splitted = pipe_separated_text.strip('|').split('|')
        
        if len(splitted) == 2:
            # In this case the pipe separated text just applies to all rows in the group
            codes = [splitted[0].strip()] * len(group)
            descriptions = [splitted[1].strip()] * len(group)
        else:
            # The pipe separated text is referring to different rows in the group
            # i.e. 386661006 | Fever (finding)|49727002 | Cough (finding) correspond to
            # 2 different rows
            codes = list()
            descriptions = list()
            first_element_none = False
            for i, (_, row) in enumerate(group.iterrows()):
                if i == 0 and row['capacity_field_choice_description'].lower() == 'none':
                    first_element_none = True
                try:
                    # If the first element is none there is no entry for it in the pipe separated field,
                    # so the indexes mismatch by 1 element
                    code = splitted[(i - first_element_none)* 2] 
                    description = splitted[(i - first_element_none) * 2 + 1]
                except IndexError:
                    code = np.nan
                    description = np.nan
                codes.append(code)
                descriptions.append(description)
    group[f'{column}_code'] = codes
    group[f'{column}_description'] = descriptions
    return group

def extract_snomed(group):
    _extract_pipe_separated(group, 'snomed')
    return group

def extract_atc(group):
    _extract_pipe_separated(group, 'atc')
    return group

df = df.groupby('capacity_field_name').apply(extract_snomed)
df = df.groupby('capacity_field_name').apply(extract_atc)

# %%
df[~pd.isna(df['snomed'])][['capacity_field_name', 'capacity_field_choice_description', 'snomed', 'snomed_code', 'snomed_description']].head(10)
# Out:
#     capacity_field_name capacity_field_choice_description  \
# 44    healthwork_erterm                               yes
# 45    healthwork_erterm                                no
# 46    healthwork_erterm                               N/A
# 47       labwork_erterm                               yes
# 48       labwork_erterm                                no
# 49       labwork_erterm                               N/A
# 99     admis_complaints          Fever (t>38C or >100.4F)
# 100    admis_complaints                             Cough
# 101    admis_complaints                       Sore throat
# 102    admis_complaints                           Dyspnea
#
#                                                 snomed snomed_code  \
# 44   223366009 | Healthcare professional (occupation)    223366009
# 45   223366009 | Healthcare professional (occupation)    223366009
# 46   223366009 | Healthcare professional (occupation)    223366009
# 47             159138004 | Microbiologist (occupation)   159138004
# 48             159138004 | Microbiologist (occupation)   159138004
# 49             159138004 | Microbiologist (occupation)   159138004
# 99   386661006 | Fever (finding)|49727002 | Cough (...  386661006
# 100  386661006 | Fever (finding)|49727002 | Cough (...   49727002
# 101  386661006 | Fever (finding)|49727002 | Cough (...  162397003
# 102  386661006 | Fever (finding)|49727002 | Cough (...   67036007
#
#                        snomed_description
# 44   Healthcare professional (occupation)
# 45   Healthcare professional (occupation)
# 46   Healthcare professional (occupation)
# 47            Microbiologist (occupation)
# 48            Microbiologist (occupation)
# 49            Microbiologist (occupation)
# 99                        Fever (finding)
# 100                       Cough (finding)
# 101             Pain in throat (finding)
# 102                    Dyspnea (finding)

# %%
df[~pd.isna(df['atc'])][['capacity_field_name', 'capacity_field_choice_description', 'atc', 'atc_code', 'atc_description']].head(10)
# Out:
#     capacity_field_name capacity_field_choice_description  \
# 202           med_nsaid                              None
# 203           med_nsaid                         Ibuprofen
# 204           med_nsaid                          Naproxen
# 205           med_nsaid                        Diclofenac
# 206           med_nsaid                                 1
# 216              carmed                              None
# 217              carmed                       Betablocker
# 218              carmed               Antiarrhytmic drugs
# 219              carmed                          Digoxine
# 220              carmed                         Diuretics
#
#                                                    atc atc_code  \
# 202  M01AE01|ibuprofen|M01AE02|naproxen|M01AB05|Dic...  M01AB05
# 203  M01AE01|ibuprofen|M01AE02|naproxen|M01AB05|Dic...  M01AE01
# 204  M01AE01|ibuprofen|M01AE02|naproxen|M01AB05|Dic...  M01AE02
# 205  M01AE01|ibuprofen|M01AE02|naproxen|M01AB05|Dic...  M01AB05
# 206  M01AE01|ibuprofen|M01AE02|naproxen|M01AB05|Dic...      NaN
# 216  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...     A10B
# 217  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...     C07A
# 218  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...     C01B
# 219  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...  C01AA05
# 220  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...      C03
#
#                                        atc_description
# 202                                         Diclofenac
# 203                                          ibuprofen
# 204                                           naproxen
# 205                                         Diclofenac
# 206                                                NaN
# 216  bloog glucose lowering drugs, excl. insulins(O...
# 217                               Beta blocking agents
# 218                   ANTIARRHYTHMICS, CLASS I AND III
# 219                                            digoxin
# 220                                          Diuretics

# %%
df.columns
# Out:
# Index(['capacity_field_name', 'capacity_field_description', 'zib',
#        'zib_concept', 'zib_codesystem', 'ehr', 'cod016_vekt_code',
#        'icd_10_code', 'capacity_field_choice_code',
#        'capacity_field_choice_description', 'snomed_code',
#        'snomed_description', 'atc_code', 'atc_description'],
#       dtype='object')

# %%
# Final set of columns
df = df[['capacity_field_name', 'capacity_field_description', 'capacity_field_choice_code',
         'capacity_field_choice_description', 'zib', 'zib_concept', 'zib_codesystem', 
         'snomed_code', 'snomed_description', 'atc_code', 'atc_description', 'ehr',
         'cod016_vekt_code', 'icd_10_code']]

# %%
df.to_csv('data/capacity-human-entered-mapping-cleaned.csv', index=False)
