# %%
import pandas as pd
import numpy as np

# %%
cd ..
# Out:
# /Users/svenvanderburg/projects/capacity/ZIB-uploader

# %% [markdown]
# ## Load excel file with mappings entered by humans from Maastro clinic
# File can be found [on the Maastro teams](https://teams.microsoft.com/l/file/CADBAFA2-9EBA-4E19-B8E4-935EA2A7974B?tenantId=b9c5dd0d-b3a0-4572-a670-e4e8bd6c9350&fileType=xlsx&objectUrl=https%3A%2F%2Fmaastro.sharepoint.com%2Fsites%2FO365GroepCDSCARRIERProjectManagement%2FShared%20Documents%2FCAPACITY%2FCodes%20mapping%20(1).xlsx&baseUrl=https%3A%2F%2Fmaastro.sharepoint.com%2Fsites%2FO365GroepCDSCARRIERProjectManagement&serviceName=teams&threadId=19:373f883c850c4e9aa697817c3cc38676@thread.skype&groupId=257a7bbf-43a5-4906-ab8e-c4deb714fc6d) or [on their sharepoint](https://maastro.sharepoint.com/sites/O365GroepCDSCARRIERProjectManagement/_layouts/15/Doc.aspx?OR=teams&action=edit&sourcedoc={CADBAFA2-9EBA-4E19-B8E4-935EA2A7974B}). Talk to Djura for access.

# %%
df = pd.read_excel('data/capacity-human-entered-mapping.xlsx', sheet_name='CAPACITY - required variables')

# %%
df.head(4)
# Out:
#                                  Variable/Field Name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
#
#                                Field Label  \
# 0    Participant Identification Number Pin
# 1  Participant Identification Number (PIN)
# 2                                 STUDY ID
# 3                                  Comple?
#
#                         Fiel Attributes      Zib                  Zib concept  \
# 0                                   NaN      NaN                          NaN
# 1                                  text  Patient  PatientIdentificationNumber
# 2                                  text      NaN                          NaN
# 3  0-Incomplete,1-Unverified,2-Complete      NaN                          NaN
#
#   Zib codesystem        EHR Snomed COD016-VEKT code ICD-10  ATC
# 0            NaN        NaN    NaN              NaN    NaN  NaN
# 1            NaN  pseudonym    NaN              NaN    NaN  NaN
# 2            NaN        NaN    NaN              NaN    NaN  NaN
# 3            NaN        NaN    NaN              NaN    NaN  NaN

# %% [markdown]
# ## Cleanup data

# %%
# Rename columns 
df.columns = ['capacity_field_name', 'capacity_field_description', 'capacity_field_attributes', 'zib', 'zib_concept', 'zib_codesystem', 'ehr', 'snomed', 'cod016_vekt_code', 'icd_10_code', 'atc']

# %%
df.head(6)
# Out:
#                                  capacity_field_name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
# 4                        inclusion_criteria_required
# 5                                            dsstdat
#
#                 capacity_field_description  \
# 0    Participant Identification Number Pin
# 1  Participant Identification Number (PIN)
# 2                                 STUDY ID
# 3                                  Comple?
# 4                       Inclusion Criteria
# 5                       Date of Enrollment
#
#               capacity_field_attributes      zib                  zib_concept  \
# 0                                   NaN      NaN                          NaN
# 1                                  text  Patient  PatientIdentificationNumber
# 2                                  text      NaN                          NaN
# 3  0-Incomplete,1-Unverified,2-Complete      NaN                          NaN
# 4                                   NaN      NaN                          NaN
# 5                            text(date)      NaN                          NaN
#
#   zib_codesystem        ehr snomed cod016_vekt_code icd_10_code  atc
# 0            NaN        NaN    NaN              NaN         NaN  NaN
# 1            NaN  pseudonym    NaN              NaN         NaN  NaN
# 2            NaN        NaN    NaN              NaN         NaN  NaN
# 3            NaN        NaN    NaN              NaN         NaN  NaN
# 4            NaN        NaN    NaN              NaN         NaN  NaN
# 5            NaN        NaN    NaN              NaN         NaN  NaN

# %% [markdown]
# ### Explode `capacity_field_attributes` column

# %%
df['capacity_field_attributes'] = df['capacity_field_attributes'].str.split(r';|,')

# %%
df = df.explode('capacity_field_attributes')
df = df.reset_index(drop=True)

# %%
df.head(10)
# Out:
#                                  capacity_field_name  \
# 0         participant_identification_number_required
# 1                                             subjid
# 2                                            studyid
# 3  participant_identification_number_pin_required...
# 4  participant_identification_number_pin_required...
# 5  participant_identification_number_pin_required...
# 6                        inclusion_criteria_required
# 7                                            dsstdat
# 8                                       sitename_nhr
# 9                                            country
#
#                 capacity_field_description capacity_field_attributes  \
# 0    Participant Identification Number Pin                       NaN
# 1  Participant Identification Number (PIN)                      text
# 2                                 STUDY ID                      text
# 3                                  Comple?              0-Incomplete
# 4                                  Comple?              1-Unverified
# 5                                  Comple?                2-Complete
# 6                       Inclusion Criteria                       NaN
# 7                       Date of Enrollment                text(date)
# 8                                Site name                       NaN
# 9                                  Country                  text (?)
#
#                   zib                  zib_concept  \
# 0                 NaN                          NaN
# 1             Patient  PatientIdentificationNumber
# 2                 NaN                          NaN
# 3                 NaN                          NaN
# 4                 NaN                          NaN
# 5                 NaN                          NaN
# 6                 NaN                          NaN
# 7                 NaN                          NaN
# 8  HealthcareProvider             OrganizationName
# 9  AddressInformation                      Country
#
#                              zib_codesystem        ehr snomed  \
# 0                                       NaN        NaN    NaN
# 1                                       NaN  pseudonym    NaN
# 2                                       NaN        NaN    NaN
# 3                                       NaN        NaN    NaN
# 4                                       NaN        NaN    NaN
# 5                                       NaN        NaN    NaN
# 6                                       NaN        NaN    NaN
# 7                                       NaN        NaN    NaN
# 8                                       NaN        NaN    NaN
# 9  CountryGBACodelist or CountryISOCodelist        NaN    NaN
#
#   cod016_vekt_code icd_10_code  atc
# 0              NaN         NaN  NaN
# 1              NaN         NaN  NaN
# 2              NaN         NaN  NaN
# 3              NaN         NaN  NaN
# 4              NaN         NaN  NaN
# 5              NaN         NaN  NaN
# 6              NaN         NaN  NaN
# 7              NaN         NaN  NaN
# 8              NaN         NaN  NaN
# 9              NaN         NaN  NaN

# %% [markdown]
# ### Split `capacity_field_attributes` column into `capacity_field_choice_code` and `capacity_field_choice_description`

# %%
def _extract_choice(string, index):
    if pd.isna(string):
        return string
    splitted = string.split('-')
    if len(splitted) == 1:
        return np.nan
    return splitted[index]


def extract_choice_code(string):
    """
    i.e. extracts 3 from '3-something'
    """
    return _extract_choice(string, 0)


def extract_choice_description(string):
    """
    i.e. extracts something from '3-something'
    """
    return _extract_choice(string, 1)
    
df['capacity_field_choice_code'] = df['capacity_field_attributes'].apply(extract_choice_code)
df['capacity_field_choice_description'] = df['capacity_field_attributes'].apply(extract_choice_description)

# %%
df[['capacity_field_choice_code', 'capacity_field_choice_description', 'capacity_field_attributes']].head(20)
# Out:
#    capacity_field_choice_code capacity_field_choice_description  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                           0                        Incomplete
# 4                           1                        Unverified
# 5                           2                          Complete
# 6                         NaN                               NaN
# 7                         NaN                               NaN
# 8                         NaN                               NaN
# 9                         NaN                               NaN
# 10                          1                               yes
# 11                          0                                no
# 12                          1                               yes
# 13                          2                                no
# 14                          3                           unknown
# 15                          1                               yes
# 16                          2                                no
# 17                          3                           unknown
# 18                          1                               yes
# 19                          2                                no
#
#    capacity_field_attributes
# 0                        NaN
# 1                       text
# 2                       text
# 3               0-Incomplete
# 4               1-Unverified
# 5                 2-Complete
# 6                        NaN
# 7                 text(date)
# 8                        NaN
# 9                   text (?)
# 10                     1-yes
# 11                      0-no
# 12                     1-yes
# 13                      2-no
# 14                 3-unknown
# 15                     1-yes
# 16                      2-no
# 17                 3-unknown
# 18                     1-yes
# 19                      2-no

# %%
df = df.drop(columns=['capacity_field_attributes'])

# %% [markdown]
# ### Split `snomed` column

# %%
df[~pd.isna(df['snomed'])][['capacity_field_name', 'snomed', 'capacity_field_choice_code', 'capacity_field_choice_description']]
# Out:
#     capacity_field_name                                             snomed  \
# 44    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 45    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 46    healthwork_erterm  223366009 | Healthcare professional (occupation)
# 47       labwork_erterm            159138004 | Microbiologist (occupation)
# 48       labwork_erterm            159138004 | Microbiologist (occupation)
# ..                  ...                                                ...
# 430      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 431      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 432      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 433      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
# 434      carhist_valve   60573004 | Aortic valve stenosis (disorder) |6...
#
#     capacity_field_choice_code capacity_field_choice_description
# 44                           1                               yes
# 45                           2                                no
# 46                           3                               N/A
# 47                           1                               yes
# 48                           2                                no
# ..                         ...                               ...
# 430                          3             Mitral valve stenosis
# 431                          4        Mitral valve regurgitation
# 432                          5     Pulmonary valve regurgitation
# 433                          7          Tricuspid valve stenosis
# 434                          8     Tricuspid valve regurgitation
#
# [276 rows x 4 columns]

# %%
df.iloc[430]['snomed']
# Out:
# '60573004 | Aortic valve stenosis (disorder) |60234000 | Aortic valve regurgitation (disorder) |48724000 | Mitral valve regurgitation (disorder) |91434003 | Pulmonic valve regurgitation (disorder) 49915006 | Tricuspid valve stenosis (disorder) |111287006 | Tricuspid valve regurgitation (disorder) |'

# %%
def extract_snomed(group):
    splitted = group['snomed'].iloc[0].strip('|').split('|')        
    if len(splitted) == 2:
        snomed_codes = [splitted[0].strip()] * len(group)
        snomed_descriptions = [splitted[1].strip()] * len(group)
    else:
        snomed_codes = list()
        snomed_descriptions = list()
        for i, (_, row) in enumerate(group.iterrows()):
            try:
                snomed_code = splitted[i * 2] 
                snomed_description = splitted[i * 2 + 1]
            except IndexError:
                snomed_code = np.nan
                snomed_description = np.nan
            snomed_codes.append(snomed_code)
            snomed_descriptions.append(snomed_description)
    group['snomed_code'] = snomed_codes
    group['snomed_description'] = snomed_descriptions
    return group
#     return pd.DataFrame({'snomed_code': snomed_codes, 'snomed_description': snomed_descriptions})    
#     return snomed_codes, snomed_descriptions

df[~pd.isna(df['snomed'])].groupby('capacity_field_name').apply(extract_snomed)[['capacity_field_name', 'capacity_field_choice_description', 'snomed_description']]
# Out:
#     capacity_field_name capacity_field_choice_description  \
# 44    healthwork_erterm                               yes
# 45    healthwork_erterm                                no
# 46    healthwork_erterm                               N/A
# 47       labwork_erterm                               yes
# 48       labwork_erterm                                no
# ..                  ...                               ...
# 430      carhist_valve              Mitral valve stenosis
# 431      carhist_valve         Mitral valve regurgitation
# 432      carhist_valve      Pulmonary valve regurgitation
# 433      carhist_valve           Tricuspid valve stenosis
# 434      carhist_valve      Tricuspid valve regurgitation
#
#                                     snomed_description
# 44                Healthcare professional (occupation)
# 45                Healthcare professional (occupation)
# 46                Healthcare professional (occupation)
# 47                         Microbiologist (occupation)
# 48                         Microbiologist (occupation)
# ..                                                 ...
# 430             Mitral valve regurgitation (disorder)
# 431   Pulmonic valve regurgitation (disorder) 49915...
# 432                                         111287006
# 433                                                NaN
# 434                                                NaN
#
# [276 rows x 3 columns]

# %% [markdown]
# TODO:
# * Fix cases where length of snomed field does not match number of choices
