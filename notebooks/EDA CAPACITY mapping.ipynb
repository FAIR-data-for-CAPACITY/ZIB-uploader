# %% [markdown]
# # Exploratory Data Analysis of CAPACITY mapping
# This notebook explores the mapping created by Louise Ferrera in excel to see how we can use this for building our conversion module from ZIB to the CAPACITY registry.

# %%
import pandas as pd
import xlrd
import itertools

# %%
mapping_path = '../../capacity_mapping.xlsx'
mapping_sheet_name = 'CAPACITY - required variables'

# The field 'Variable/Field Name' contains the formal field name in REDCap
field_name_col = 'Variable/Field Name'

# %%
mapping_df = pd.read_excel(mapping_path, sheet_name=mapping_sheet_name)
display(mapping_df)
# Out:
#                                    Variable/Field Name  \
# 0           participant_identification_number_required
# 1                                               subjid
# 2                                              studyid
# 3    participant_identification_number_pin_required...
# 4                          inclusion_criteria_required
# ..                                                 ...
# 145                                   carhist_tr_date
# 146                               carhist_valve_treat
# 147                                     carhist_other
# 148                                   carhist_other_2
# 149  capacity_cardiac_baseline_ass essment_required...
#
#                                            Field Label  \
# 0                Participant Identification Number Pin
# 1              Participant Identification Number (PIN)
# 2                                             STUDY ID
# 3                                              Comple?
# 4                                   Inclusion Criteria
# ..                                                 ...
# 145  (just if the ﬁeld: [carhist_valve(8)] = '1') t...
# 146  (just if the ﬁeld: [carhist(4)] = '1') Valvula...
# 147  (just if the ﬁeld: [carhist(99)] = '1') Specif...
# 148  (just if the ﬁeld: [carhist(99)] = '1') Specif...
# 149                                           Complete
#
#                                        Fiel Attributes        Zib  \
# 0                                                  NaN        NaN
# 1                                                 text    Patient
# 2                                                 text        NaN
# 3                 0-Incomplete,1-Unverified,2-Complete        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 145                                        Text (date)    Problem
# 146  1- No intervention performed; 2-Intervention p...  Procedure
# 147                                               Text    Problem
# 148                                        Text (date)    Problem
# 149              0-Incomplete; 1-Unverified;2-Complete        NaN
#
#                      Zib concept Zib codesystem        EHR Snomed  \
# 0                            NaN            NaN        NaN    NaN
# 1    PatientIdentificationNumber            NaN  pseudonym    NaN
# 2                            NaN            NaN        NaN    NaN
# 3                            NaN            NaN        NaN    NaN
# 4                            NaN            NaN        NaN    NaN
# ..                           ...            ...        ...    ...
# 145             ProblemStartDate            NaN        NaN    NaN
# 146                          NaN            NaN        NaN    NaN
# 147                  ProblemName            NaN        NaN    NaN
# 148             ProblemStartDate            NaN        NaN    NaN
# 149                          NaN            NaN        NaN    NaN
#
#     COD016-VEKT code ICD-10  ATC
# 0                NaN    NaN  NaN
# 1                NaN    NaN  NaN
# 2                NaN    NaN  NaN
# 3                NaN    NaN  NaN
# 4                NaN    NaN  NaN
# ..               ...    ...  ...
# 145              NaN    NaN  NaN
# 146              NaN    NaN  NaN
# 147              NaN    NaN  NaN
# 148              NaN    NaN  NaN
# 149              NaN    NaN  NaN
#
# [150 rows x 11 columns]

# %%
# Focus on cardiovascular medication
carmed_mapping = mapping_df[(mapping_df[field_name_col].str.startswith('carmed'))]
display(carmed_mapping)
# Out:
#         Variable/Field Name  \
# 78          carmed_examples
# 79                   carmed
# 80                carmed_bb
# 81          carmed_bb_spec
# 82         carmed_antiarrh
# 83   carmed_arrhyth_class1
# 84    carmed_arrhyth_class3
# 85   carmed_arrhyth_class4
# 86    carmed_antiarrh_spec
# 87         carmed_diuretic
# 88    carmed_diuretic_spec
# 89          carmed_cablock
# 90     carmed_cablock_spec
# 91             carmed_acei
# 92        carmed_acei_spec
# 93       carmed_ace_dosage
# 94     carmed_acei_chronic
# 95              carmed_arb
# 96         carmed_arb_spec
# 97      carmed_arb_chronic
# 98       carmed_arb_dosage
# 99              carmed_mra
# 100            carmed_pde5
# 101       carmed_antiplate
# 102  carmed_antiplate_spec
# 103            carmed_coum
# 104            carmed_doac
# 105       carmed_doac_spec
# 106           carmed_lipid
# 107      carmed_lipid_spec
# 108          carmed_oraldm
# 109     carmed_oraldm_spec
# 110           carmed_other
#
#                                            Field Label  \
# 78   Cardiovascular medication classiﬁcation system...
# 79                          Cardiovascular medications
# 80   (just if the field:[carmed(1)] = '1')Betablockers
# 81   (just if the ﬁeld[carmed_bb(99)] = '1') Specif...
# 82   (just if the ﬁeld [carmed(3)] = '1') Antiarrhy...
# 83   (just if the ﬁeld: [carmed_antiarrh(1)] = '1')...
# 84   (just if the ﬁeld: [carmed_antiarrh(3)] = '1')...
# 85   (just if the ﬁeld: [carmed_antiarrh(4)] = '1')...
# 86   ( just if the field [carmed_antiarrh(99)]=1) S...
# 87      (just if the ﬁeld: [carmed(5)] = '1')Diuretics
# 88   (just if the ﬁeld: [carmed_diuretic(99)] = '1'...
# 89   (just if the ﬁeld: [carmed(6)] = '1') Calcium ...
# 90   (just if the ﬁeld: [carmed_cablock] = '99') Sp...
# 91   (just if the ﬁeld: [carmed(7)] = '1') ACE inhi...
# 92   (just if the ﬁeld: [carmed_acei] = '99') Speci...
# 93   (just if the ﬁeld: [carmed(7)] = '1')ACE inhib...
# 94   (just if the ﬁeld: [carmed(7)] = '1') ACE inhi...
# 95   (just if the ﬁeld: [carmed(8)] = '1') Angioten...
# 96   (just if the ﬁeld: [carmed_arb] = '99')Specify...
# 97   (just if the ﬁeld: [carmed(8)] = '1')Angiotens...
# 98   (just if the field [carmed(8)]=1) Angiotensin ...
# 99   (just if the ﬁeld: [carmed(15)] = '1') Aldoste...
# 100  (just if the field: [carmed(17)]='1')Phosphodi...
# 101  (just if the ﬁeld if: [carmed(9)] = '1')Anti-p...
# 102   (just if the ﬁeld: [carmed_antiplate(99)] = '1')
# 103    (just if the field [carmed(10)] = '1') Coumarin
# 104  (just if the ﬁeld: [carmed(11)] = '1') Direct ...
# 105  (just if the ﬁeld: [carmed_doac] = '99') Speci...
# 106  (just if the ﬁeld: [carmed(12)] = '1')Lipid lo...
# 107  (just if the ﬁeld: [carmed_lipid(99)] = '1') S...
# 108  (just if the ﬁeld: [carmed(14)] = '1') Oral an...
# 109  (just if the ﬁeld: [carmed_oraldm(99)] = '1') ...
# 110  (just if the ﬁeld: [carmed(99)] = '1') Other c...
#
#                                        Fiel Attributes                   Zib  \
# 78                                         descriptive                   NaN
# 79   0-None; 1-Betablocker; 3-Antiarrhytmic drugs, ...  FarmaceuticalProduct
# 80   1- Atenolol; 2-Bisoprolol;3-Carvedilol;4-Labet...  FarmaceuticalProduct
# 81                                                text  FarmaceuticalProduct
# 82     1- Class I; 3-Class III; 4- Class IV, 99- other  FarmaceuticalProduct
# 83   1- 1a-Quinidine; 2- 1a-Disopyramide; 3- 1a-Pro...  FarmaceuticalProduct
# 84   1- Amiodarone; 2- Sotalol; 3- Ibutilide; 4- Do...  FarmaceuticalProduct
# 85                             1-Diltiazem;2-Verapamil  FarmaceuticalProduct
# 86                                                text  FarmaceuticalProduct
# 87   1-Bumetanide(Burinex);2-Chlortalidon;3-Furosem...  FarmaceuticalProduct
# 88                                                Text  FarmaceuticalProduct
# 89   1- Amlodipin;2-Barnidipin(Cyress, Vasexten);3-...  FarmaceuticalProduct
# 90                                                Text  FarmaceuticalProduct
# 91   1-Captopril;2-Enalapril;3-Lisinopril(Zestril);...  FarmaceuticalProduct
# 92                                                Text  FarmaceuticalProduct
# 93                                                Text   MedicationAgreement
# 94                           1-yes, 0-none, -1 unknown         MedicationUse
# 95   1- Candesartan(Atacand);2-Irbesartan(Aprovel);...  FarmaceuticalProduct
# 96                                                Text  FarmaceuticalProduct
# 97                           1-yes, 0-none, -1 unknown         MedicationUse
# 98                                                Text   MedicationAgreement
# 99                         1-Spironolacton;2-Eplerenon  FarmaceuticalProduct
# 100   1-Avanafil;2-Sildenafil;3Tadalafil;4-Vardenaifil  FarmaceuticalProduct
# 101  1-Acetylsalicylic acid;2-Carbasalate calcium;3...  FarmaceuticalProduct
# 102                                               Text  FarmaceuticalProduct
# 103    1- Acenocoumarol; 2- Phenprocoumon ( Marcoumar)  FarmaceuticalProduct
# 104  1- Apixaban (Eliquis); 2- Dabigatran(Pradaxa);...  FarmaceuticalProduct
# 105                                               Text  FarmaceuticalProduct
# 106  1- Atorvastatin (Lipitor); 2-Ciprofibrate(Moda...  FarmaceuticalProduct
# 107                                               Text  FarmaceuticalProduct
# 108  1- Gliclazide (Diamicron); 2- Glimepiride (Ama...  FarmaceuticalProduct
# 109                                               Text  FarmaceuticalProduct
# 110                                               Text  FarmaceuticalProduct
#
#                               Zib concept Zib codesystem  EHR  \
# 78                                    NaN            NaN  NaN
# 79   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 80   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 81   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 82   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 83   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 84   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 85   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 86   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 87   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 88   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 89   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 90   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 91   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 92   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 93                     InstructionsForUse            NaN  NaN
# 94      PeriodOfUse/TimeInterval/Duration            NaN  NaN
# 95   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 96   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 97      PeriodOfUse/TimeInterval/Duration            NaN  NaN
# 98                     InstructionsForUse            NaN  NaN
# 99   AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 100  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 101  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 102  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 103  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 104  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 105  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 106  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 107  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 108  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 109  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
# 110  AgreedMedicine::FarmaceuticalProduct  Snomed CT/ATC  NaN
#
#                                                 Snomed COD016-VEKT code  \
# 78                                                 NaN              NaN
# 79   373254001 | Substance with beta adrenergic rec...              NaN
# 80   387506000 | Atenolol (substance) |386868003 | ...              NaN
# 81                                                 NaN              NaN
# 82   373260001 | Class I antiarrhythmic agent (subs...              NaN
# 83   372697008 | Quinidine (substance) |2844004 | D...              NaN
# 84   72821002 | Amiodarone (substance) |372911006 |...              NaN
# 85   72793000 | Diltiazem (substance) |72754009 | V...              NaN
# 86                                                 NaN              NaN
# 87   387498005 | Bumetanide (substance) |387324004 ...              NaN
# 88                                                 NaN              NaN
# 89   386864001 | Amlodipine (substance) |698052006 ...              NaN
# 90                                                 NaN              NaN
# 91   387160004 | Captopril (substance) |372658000 |...              NaN
# 92                                                 NaN              NaN
# 93                                                 NaN              NaN
# 94                                                 NaN              NaN
# 95   372512008 | Candesartan (substance) |386877005...              NaN
# 96                                                 NaN              NaN
# 97                                                 NaN              NaN
# 98                                                 NaN              NaN
# 99   387078006 | Spironolactone (substance) |407010...              NaN
# 100  703956007 | Avanafil (substance) |372572000 | ...              NaN
# 101  387458008 | Aspirin (substance) |111122008 | C...              NaN
# 102                                                NaN              NaN
# 103  387457003 | Acenocoumarol (substance) |5948800...              NaN
# 104  698090000 | Apixaban (substance) |698871007 | ...              NaN
# 105                                                NaN              NaN
# 106  373444002 | Atorvastatin (substance) |39595700...              NaN
# 107                                                NaN              NaN
# 108  386966003 | Glimepiride (substance) |386966003...              NaN
# 109                                                NaN              NaN
# 110                                                NaN              NaN
#
#     ICD-10                                                ATC
# 78     NaN                                                NaN
# 79     NaN  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...
# 80     NaN  C07AB03|Atenolol|C07AB07|Bisoprolol|C07AG02|Ca...
# 81     NaN                                                NaN
# 82     NaN  C01BA|Antiarrhythmics, class Ia|C01BB|Antiarrh...
# 83     NaN  C01BA01|Quinidine |C01BA03|Disopyramide|C01BA0...
# 84     NaN  C01BD01|amiodarone|C07AA07|sotalol|C01BD05|ibu...
# 85     NaN                C08DB01|diltiazem|C08DA01|verapamil
# 86     NaN                                                NaN
# 87     NaN  C03CA02|bumetanide|C03BA04|chlortalidone|C03CA...
# 88     NaN                                                NaN
# 89     NaN  C08CA01|amlodipine|C08CA12|barnidipine|C08CA05...
# 90     NaN                                                NaN
# 91     NaN  C08CA05|captopril|C09AA02| enalapril|C09AA03|l...
# 92     NaN                                                NaN
# 93     NaN                                                NaN
# 94     NaN                                                NaN
# 95     NaN  C09CA06|Candesartan|C09CA04|irbesartan|C09CA01...
# 96     NaN                                                NaN
# 97     NaN                                                NaN
# 98     NaN                                                NaN
# 99     NaN          C03DA01|spironolactone|C03DA04|eplerenone
# 100    NaN  G04BE10|avanafil|G04BE03|sildenafil|G04BE08|ta...
# 101    NaN  B01AC06|acetylsalicylic acid|B01AC08| carbasal...
# 102    NaN                                                NaN
# 103    NaN        B01AA07|acenocoumarol|B01AA04|phenprocoumon
# 104    NaN  B01AF02|apixaban|B01AE07|dabigatran etexilate|...
# 105    NaN                                                NaN
# 106    NaN  C10AA05|Atorvastatin|C10AB08|ciprofibrate|C10A...
# 107    NaN                                                NaN
# 108    NaN  A10BB09|gliclazide|A10BB12|glimepiride|A10BA02...
# 109    NaN                                                NaN
# 110    NaN                                                NaN

# %%
carmed_mapping[[field_name_col, 'ATC']]
# Out:
#         Variable/Field Name                                                ATC
# 78          carmed_examples                                                NaN
# 79                   carmed  C07A|Beta blocking agents|C01B|ANTIARRHYTHMICS...
# 80                carmed_bb  C07AB03|Atenolol|C07AB07|Bisoprolol|C07AG02|Ca...
# 81          carmed_bb_spec                                                 NaN
# 82         carmed_antiarrh   C01BA|Antiarrhythmics, class Ia|C01BB|Antiarrh...
# 83   carmed_arrhyth_class1   C01BA01|Quinidine |C01BA03|Disopyramide|C01BA0...
# 84    carmed_arrhyth_class3  C01BD01|amiodarone|C07AA07|sotalol|C01BD05|ibu...
# 85   carmed_arrhyth_class4                 C08DB01|diltiazem|C08DA01|verapamil
# 86    carmed_antiarrh_spec                                                 NaN
# 87         carmed_diuretic   C03CA02|bumetanide|C03BA04|chlortalidone|C03CA...
# 88    carmed_diuretic_spec                                                 NaN
# 89          carmed_cablock   C08CA01|amlodipine|C08CA12|barnidipine|C08CA05...
# 90     carmed_cablock_spec                                                 NaN
# 91             carmed_acei   C08CA05|captopril|C09AA02| enalapril|C09AA03|l...
# 92        carmed_acei_spec                                                 NaN
# 93       carmed_ace_dosage                                                 NaN
# 94     carmed_acei_chronic                                                 NaN
# 95              carmed_arb   C09CA06|Candesartan|C09CA04|irbesartan|C09CA01...
# 96         carmed_arb_spec                                                 NaN
# 97      carmed_arb_chronic                                                 NaN
# 98       carmed_arb_dosage                                                 NaN
# 99              carmed_mra           C03DA01|spironolactone|C03DA04|eplerenone
# 100            carmed_pde5   G04BE10|avanafil|G04BE03|sildenafil|G04BE08|ta...
# 101       carmed_antiplate   B01AC06|acetylsalicylic acid|B01AC08| carbasal...
# 102  carmed_antiplate_spec                                                 NaN
# 103            carmed_coum         B01AA07|acenocoumarol|B01AA04|phenprocoumon
# 104            carmed_doac   B01AF02|apixaban|B01AE07|dabigatran etexilate|...
# 105       carmed_doac_spec                                                 NaN
# 106           carmed_lipid   C10AA05|Atorvastatin|C10AB08|ciprofibrate|C10A...
# 107      carmed_lipid_spec                                                 NaN
# 108          carmed_oraldm   A10BB09|gliclazide|A10BB12|glimepiride|A10BA02...
# 109     carmed_oraldm_spec                                                 NaN
# 110           carmed_other                                                 NaN

# %% [markdown]
# There is a lot of information embedded int the ATC column. For the fields with multiple choice answers every ATC code is paired with its official name. We need to unpack this information and isolate the ATC codes.

# %%
atc_mappings = carmed_mapping['ATC'][carmed_mapping['ATC'].notnull()]

# Turn pipe-separated data into list
atc_mappings = atc_mappings.str.split('|')

# Remove whitespace
atc_mappings = atc_mappings.apply(lambda x: [y for y in x if y and not y.isspace()])

# Pair codes with their official name
atc_mappings = atc_mappings.apply(lambda x: [tuple(x[i:i+2]) for i in range(0, len(x), 2)])

display(atc_mappings)
atc_codes = atc_mappings.apply(lambda x: [t[0] for t in x])
display(atc_codes)
# Out:
# 79     [(C07A, Beta blocking agents), (C01B, ANTIARRH...
# 80     [(C07AB03, Atenolol), (C07AB07, Bisoprolol), (...
# 82     [(C01BA, Antiarrhythmics, class Ia), (C01BB, A...
# 83     [(C01BA01, Quinidine ), (C01BA03, Disopyramide...
# 84     [(C01BD01, amiodarone), (C07AA07, sotalol), (C...
# 85          [(C08DB01, diltiazem), (C08DA01, verapamil)]
# 87     [(C03CA02, bumetanide), (C03BA04, chlortalidon...
# 89     [(C08CA01, amlodipine), (C08CA12, barnidipine)...
# 91     [(C08CA05, captopril), (C09AA02,  enalapril), ...
# 95     [(C09CA06, Candesartan), (C09CA04, irbesartan)...
# 99     [(C03DA01, spironolactone), (C03DA04, eplereno...
# 100    [(G04BE10, avanafil), (G04BE03, sildenafil), (...
# 101    [(B01AC06, acetylsalicylic acid), (B01AC08,  c...
# 103    [(B01AA07, acenocoumarol), (B01AA04, phenproco...
# 104    [(B01AF02, apixaban), (B01AE07, dabigatran ete...
# 106    [(C10AA05, Atorvastatin), (C10AB08, ciprofibra...
# 108    [(A10BB09, gliclazide), (A10BB12, glimepiride)...
# Name: ATC, dtype: object
# 79     [C07A, C01B, C01AA05, C03, C08, C09A , C09C, C...
# 80     [C07AB03, C07AB07, C07AG02, C07AG01, C07AB02, ...
# 82                     [C01BA, C01BB, C01BC, C01BD, C08]
# 83     [C01BA01, C01BA03, C01BA02, C01BB01, N03AB02, ...
# 84                  [C01BD01, C07AA07, C01BD05, C01BD04]
# 85                                    [C08DB01, C08DA01]
# 87                  [C03CA02, C03BA04, C03CA01, C03AA03]
# 89                           [C08CA01, C08CA12, C08CA05]
# 91                  [C08CA05, C09AA02, C09AA03, C09AA04]
# 95                  [C09CA06, C09CA04, C09CA01, C09CA03]
# 99                                    [C03DA01, C03DA04]
# 100                 [G04BE10, G04BE03, G04BE08, G04BE09]
# 101    [B01AC06, B01AC08, B01AC04, B01AC07, B01AC22, ...
# 103                                   [B01AA07, B01AA04]
# 104                 [B01AF02, B01AE07, B01AF03, B01AF01]
# 106    [C10AA05, C10AB08, C10AX13, C10AX09, C10AB04, ...
# 108                   [A10BB09, A10BB12, A10BA02, ?????]
# Name: ATC, dtype: object
