# %%
import rdflib
import requests
import io

# %%
FHIR_RDF_URL = 'https://www.hl7.org/fhir/stu3/fhir.ttl'

# %%
response = requests.get(FHIR_RDF_URL)
graph = rdflib.Graph().parse(io.BytesIO(response.content), format='turtle')

# %%
graph.all_nodes()
# Out:
# {rdflib.term.Literal('Id of referenced rule within the ruleset'),
#  rdflib.term.Literal('Annual or lifetime'),
#  rdflib.term.Literal('The clinical status of the allergy or intolerance.'),
#  rdflib.term.URIRef('http://hl7.org/fhir/AuditEvent.entity.query'),
#  rdflib.term.BNode('ub2bL39620C26'),
#  rdflib.term.BNode('ub2bL642C26'),
#  rdflib.term.BNode('ub2bL49346C26'),
#  rdflib.term.URIRef('http://hl7.org/fhir/QuestionnaireResponse.item.answer.value'),
#  rdflib.term.Literal('Kind of resource to include in the list'),
#  rdflib.term.Literal("The match value may be either a code defined by the system, or a string value, which is a regex match on the literal string of the property value when the operation is 'regex', or one of the values (true and false), when the operation is 'exists'."),
#  rdflib.term.URIRef('http://hl7.org/fhir/CapabilityStatement.rest'),
#  rdflib.term.Literal('Formal identifier for the property'),
#  rdflib.term.BNode('ub2bL23531C26'),
# ...
